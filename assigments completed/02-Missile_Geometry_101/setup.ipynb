# %%
import sys
print("Python executable:\n", sys.executable)

assert ".venv" in sys.executable, """
WRONG KERNEL.
Pick the kernel that ends with '(.venv)' (e.g., 4543 02 Missile Geo (.venv)).
"""
print("✅ Using .venv kernel")
# Out:
# Python executable:
#  /Users/ricardoayala/Desktop/ricardoayala2510-Spatial-Data-Mapping/.venv/bin/python
# ✅ Using .venv kernel

# %%
import sys
print(sys.executable)
# !{sys.executable} -m pip install folium branca pyshp geojson rich shapely
# Out:
# /Users/ricardoayala/Desktop/ricardoayala2510-Spatial-Data-Mapping/.venv/bin/python
# ...

# %%
import folium
import shapefile
import shapely
import geojson
import numpy
import rich


print("✅ Imports OK")
print("pyshp (shapefile) from:", shapefile.__file__)
# Out:
# ✅ Imports OK
# pyshp (shapefile) from: /Users/ricardoayala/Desktop/ricardoayala2510-Spatial-Data-Mapping/.venv/lib/python3.9/site-packages/shapefile.py

# %%
import folium

m = folium.Map(location=[0, 0], zoom_start=2, tiles="OpenStreetMap")
