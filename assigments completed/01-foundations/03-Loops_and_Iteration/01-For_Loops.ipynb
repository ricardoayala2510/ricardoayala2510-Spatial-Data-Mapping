# %% [markdown]
# # 01 - For Loops
#
# Learn how to use `for` loops to iterate over sequences.
#
# ## Learning Goals
# - Use `for` with lists, strings, and `range()`
# - Understand loop variables and block structure

# %% [markdown]
# ## Loop over a list

# %%
fruits = ['apple', 'banana', 'cherry']
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ## Loop over characters in a string

# %%
word = 'hello'
for char in word:
    print(char)
# Out:
# h
# e
# l
# l
# o

# %% [markdown]
# ## Using `range()`

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Loop with math

# %%
for i in range(1, 6):
    print(f'{i} squared is', i ** 2)
# Out:
# 1 squared is 1
# 2 squared is 4
# 3 squared is 9
# 4 squared is 16
# 5 squared is 25

# %% [markdown]
# ## Your Turn
#
# Loop over a list of 3 favorite movies and print them in all caps.

# %%
movies = ['Inception', 'Interstellar', 'Coco']

for movie in movies:
    print(movie.upper())
# Out:
# INCEPTION
# INTERSTELLAR
# COCO
