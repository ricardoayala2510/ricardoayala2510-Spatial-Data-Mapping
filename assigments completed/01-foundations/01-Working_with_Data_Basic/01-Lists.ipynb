# %% [markdown]
# # 📘 01 - Python Lists
#
# Explore how to use lists to store and manipulate data.
#
# ## ✅ Learning Goals
# - Create and modify Python lists
# - Access elements using indexing
# - Use list methods like `append()`, `remove()`, and `sort()`

# %% [markdown]
# ## 🔧 Create a List

# %%
my_list = [10, 20, 30, 40, 50]
print(my_list)
# Out:
# [10, 20, 30, 40, 50]

# %% [markdown]
# ## 🎯 Access Elements

# %%
print('First item:', my_list[0])
print('Last item:', my_list[-1])
# Out:
# First item: 10
# Last item: 50

# %% [markdown]
# ## ➕ Modify List

# %%
my_list.append(60)
my_list.remove(30)
print(my_list)
# Out:
# [10, 20, 40, 50, 60]

# %% [markdown]
# ## 🔁 Loop Through List

# %%
for item in my_list:
    print(item)
# Out:
# 10
# 20
# 40
# 50
# 60

# %% [markdown]
# ## ✏️ Your Turn
# Create your own list of 5 favorite movies and sort them alphabetically.

# %%
# ✏️ Your Turn
# Create your own list of 5 favorite movies and sort them alphabetically.

movies = ["Interstellar", "The Dark Knight", "Inception", "Parasite", "Whiplash"]
movies.sort()  # sorts A → Z
print(movies)

# Optional: print one per line
for m in movies:
    print(m)
# Out:
# ['Inception', 'Interstellar', 'Parasite', 'The Dark Knight', 'Whiplash']
# Inception
# Interstellar
# Parasite
# The Dark Knight
# Whiplash
