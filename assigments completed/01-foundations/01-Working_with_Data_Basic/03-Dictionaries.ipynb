# %% [markdown]
# # 03 - Python Dictionaries
#
# Dictionaries store key-value pairs for fast lookups.
#
# ## Your Turn
# Create a dictionary to store information about your favorite book.

# %%
# Favorite book dictionary
favorite_book = {
    'title': '1984',
    'author': 'George Orwell',
    'year': 1949,
    'genre': 'Dystopian Fiction'
}

print(favorite_book)
# Out:
# {'title': '1984', 'author': 'George Orwell', 'year': 1949, 'genre': 'Dystopian Fiction'}

# %%
# Access values
print(favorite_book['title'])
print(favorite_book.get('rating', 'Not provided'))
# Out:
# 1984
# Not provided

# %%
# Loop over the dictionary
for key, value in favorite_book.items():
    print(key, '->', value)
# Out:
# title -> 1984
# author -> George Orwell
# year -> 1949
# genre -> Dystopian Fiction
