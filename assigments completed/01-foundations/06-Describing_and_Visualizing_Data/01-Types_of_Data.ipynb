# %% [markdown]
# # 📊 Types of Data
#
# In order to analyze and visualize data properly, we first need to understand the types of data we’re dealing with.
#
# This notebook covers:
#
# - Qualitative vs Quantitative data
# - Discrete vs Continuous data
# - The four scales of measurement: Nominal, Ordinal, Interval, Ratio
#
# ⚡ Choosing the right summary statistic or plot depends on the data type.

# %% [markdown]
# ## 1. Qualitative vs Quantitative
#
# **Qualitative (Categorical):** Describes categories or labels.
# Examples: eye color, brand of phone, type of pet
#
# **Quantitative (Numeric):** Represents measurable quantities.
# Examples: age, height, salary

# %%
# Example: classify the following
data = {
    "Eye Color": ["Blue", "Brown", "Green", "Hazel"],
    "Age": [18, 21, 35, 42],
    "Favorite Pet": ["Dog", "Cat", "Fish", "Bird"],
    "Height_cm": [160, 175, 180, 155]
}

import pandas as pd
df = pd.DataFrame(data)
df
# Out:
#   Eye Color  Age Favorite Pet  Height_cm
# 0      Blue   18          Dog        160
# 1     Brown   21          Cat        175
# 2     Green   35         Fish        180
# 3     Hazel   42         Bird        155

# %% [markdown]
# ### Classification
#
# - **Eye Color** → Qualitative
# - **Age** → Quantitative
# - **Favorite Pet** → Qualitative
# - **Height_cm** → Quantitative

# %% [markdown]
# ## 2. Discrete vs Continuous
#
# **Discrete:** Countable values, often whole numbers.
# Examples: number of children, dice rolls
#
# **Continuous:** Infinite possible values within a range.
# Examples: height, weight, temperature
#
# Both discrete and continuous variables are **quantitative**, but they are often handled differently in analysis and visualization.

# %% [markdown]
# ## 3. Scales of Measurement
#
# - **Nominal** – categories with no order
#   Example: eye color, blood type
#
# - **Ordinal** – categories with an order, but not evenly spaced
#   Example: t-shirt size (S, M, L)
#
# - **Interval** – numeric, equal intervals, but no true zero
#   Example: temperature in °C
#
# - **Ratio** – numeric, equal intervals, meaningful zero
#   Example: height, weight, age

# %%
# Small exercise: classify the following variables
variables = [
    ("Movie Genre", "Nominal"),
    ("Exam Letter Grade", "Ordinal"),
    ("Temperature in Celsius", "Interval"),
    ("Height in cm", "Ratio"),
    ("Number of Siblings", "Ratio")
]

for var, classification in variables:
    print(f"{var} → {classification}")
# Out:
# Movie Genre → Nominal
# Exam Letter Grade → Ordinal
# Temperature in Celsius → Interval
# Height in cm → Ratio
# Number of Siblings → Ratio

# %% [markdown]
# ## 4. Quick Practice
#
# Decide for each variable:
#
# - Is it qualitative or quantitative?
# - If quantitative, is it discrete or continuous?
# - What scale of measurement does it use?

# %% [markdown]
# | Variable | Qual/Quant | Disc/Cont | Scale |
# |---|---|---|---|
# | Country of Birth | Qualitative | – | Nominal |
# | Shoe Size | Quantitative | Discrete | Ordinal |
# | Time to Run 5k | Quantitative | Continuous | Ratio |
# | Temperature (°C) | Quantitative | Continuous | Interval |
# | Number of Pets | Quantitative | Discrete | Ratio |

# %% [markdown]
# ## Notes
#
# - **Country of Birth** is qualitative because it is a category with no order.
# - **Shoe Size** is usually treated as quantitative and discrete because it takes fixed step values, but it also has an ordered structure.
# - **Time to Run 5k** has a true zero and can vary continuously, so it is ratio.
# - **Temperature in Celsius** is interval because zero does not mean “no temperature.”
# - **Number of Pets** is ratio because zero pets is meaningful and the values are countable.

# %% [markdown]
# ## Summary
#
# Understanding data types helps you choose:
#
# - the right graph
# - the right summary statistics
# - the right analysis method
#
# Next up: **Summary Statistics**
